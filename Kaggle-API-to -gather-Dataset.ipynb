# %%
# !pip install -q kaggle # connecting kaggle

# %%
# !mkdir ~/.kaggle    # create a kaggle directory

# %%
# !cp kaggle.json ~/.kaggle # copying json file to folder

# %%
# !kaggle datasets download -d shivd24coder/fifa-world-cup-dataset    # from kaggle dataset field copy API command
# Out:
# ...
#   0% 0.00/372k [00:00<?, ?B/s]
# 100% 372k/372k [00:00<00:00, 113MB/s]

# %%
# !unzip /content/fifa-world-cup-dataset.zip
# Out:
# Archive:  /content/fifa-world-cup-dataset.zip
#   inflating: Goals.csv
#   inflating: Team.csv
#   inflating: attendence.csv
#   inflating: match.csv

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Team.csv')
df
# Out:
#       No  Pos             Player                                 DOB/Age Caps  \
# 0      1  1GK       Ángel Bossio        (1905-05-05)5 May 1905 (aged 25)  NaN
# 1      1  1GK       Juan Botasso   (1908-10-23)23 October 1908 (aged 21)  NaN
# 2      9  4FW     Roberto Cherro  (1907-02-23)23 February 1907 (aged 23)  NaN
# 3      4  2DF  Alberto Chividini  (1907-02-23)23 February 1907 (aged 23)  NaN
# 4     10  4FW    Attilio Demaría     (1909-03-19)19 March 1909 (aged 21)  NaN
# ...   ..  ...                ...                                     ...  ...
# 8892   -  4FW     Park Chu-Young      (1985-07-10)10 July 1985 (aged 28)   62
# 8893   -  4FW        Ji Dong-Won       (1991-05-28)28 May 1991 (aged 23)   26
# 8894   -  4FW        Lee Keun-Ho     (1985-04-11)11 April 1985 (aged 29)   62
# 8895   -  4FW       Koo Ja-Cheol  (1989-02-27)27 February 1989 (aged 25)   35
# 8896   -  4FW      Kim Shin-Wook     (1988-04-14)14 April 1988 (aged 26)   26
#
# ...

# %%
df.isnull().any()
# Out:
# No              True
# Pos            False
# Player         False
# DOB/Age         True
# Caps            True
# Club           False
# Country        False
# ClubCountry    False
# Year           False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# No               24
# Pos               0
# Player            0
# DOB/Age          92
# Caps           2811
# Club              0
# Country           0
# ClubCountry       0
# Year              0
# dtype: int64
